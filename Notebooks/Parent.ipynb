# %%
config = {
    "catalog_name": "olist_db"
    , "schema_name": "bronze"
    , "table_names": ["customers", "geolocation", "order_items", "order_payments", "order_reviews", "orders", "products", "sellers", "product_category_name_translation"]
}

# %%
dbutils.jobs.taskValues.set(key="catalog_name", value=config["catalog_name"])
dbutils.jobs.taskValues.set(key="schema_name", value=config["schema_name"])
dbutils.jobs.taskValues.set(key="table_names", value=config["table_names"])
